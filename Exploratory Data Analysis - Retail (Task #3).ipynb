# %% [markdown]
# # Exploratory Data Analysis - Retail
#
# ## GRIP @ Sparks Foundation
#
# ### Internship Task3: Exploratory Data analysis - Retail
#
# #### Author: Khizer Ahmed Biyabani

# %% [markdown]
# Here we are going to perform an exploratory analysis on the given dataset of a retail store.

# %%
#importing the necessary libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing the data-set
data=pd.read_csv('SampleSuperstore.csv')

# %%
#Viewing the first five rows of the data set.
data.head(5)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %% [markdown]
# The country is not necessary. So we can drop that column.

# %%
data=data.drop(['Country'],axis=1)
data.head(5)
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ### PRODUCT LEVEL ANALYSIS

# %%
data['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
data['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
data['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
#Lets see how sub-categories are distributed wrt to category
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category',data=data,color='y')
plt.xlabel('Sub-Category')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# Hence, we can find which of the items belong to several categories. And we can infer that maximum products are the office suplies.

# %%
plt.figure(figsize=(12,10))
data['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %% [markdown]
# The store has wide variety of Office Supplies especially in Binders and Paper department.

# %%
data.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.title('Total Profit and Sales per Sub-Category')
plt.show()

# %% [markdown]
# Hence, the highest profit is earned in Copiers while Selling price for Chairs and Phones is extremely high compared to other products. Another interesting fact- people dont prefer to buy Tables and Bookcases from Superstore. Hence these departments are in loss.

# %%
data['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="Sub-Category", hue="Region", data=data)
plt.show()

# %% [markdown]
# People residing in Western part of US tend to order more from superstore.

# %%
data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="Sub-Category", hue="Ship Mode", data=data)
plt.show()df['Cost']=df['Sales']-df['Profit']
df['Cost'].head()

# %% [markdown]
# Hence, we can infer that maximum products of this superstore is shipped in a Standart Class mode. Also, there are less products shipped on the same day.

# %%
data.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit  \
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164
#
#         Cost   Profit %
# 0   220.0464  19.047619
# ...

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="Sub-Category", hue="Segment", data=data)
plt.show()

# %% [markdown]
# Hence, the residents if US buy commodities from this superstore.

# %%
data['Cost']=data['Sales']-data['Profit']
data['Cost'].head()
# Out:
# 0     220.0464
# 1     512.3580
# 2       7.7486
# 3    1340.6085
# 4      19.8516
# Name: Cost, dtype: float64

# %%
data['Profit %']=(data['Profit']/data['Cost'])*100

# %%
#Profit Percentage of first 5 product sub-categories
data.iloc[[0,1,2,3,4],[7,13]]
# Out:
#   Sub-Category   Profit %
# 0    Bookcases  19.047619
# 1       Chairs  42.857143
# 2       Labels  88.679245
# 3       Tables -28.571429
# 4      Storage  12.676056

# %%
#Products with high Profit Percentage 
data.sort_values(['Profit %','Sub-Category'],ascending=False).groupby('Profit %').head(5)
# Out:
#            Ship Mode      Segment             City           State  \
# 1696    Second Class  Home Office          Bayonne      New Jersey
# 2592    Second Class    Corporate      Summerville  South Carolina
# 6338  Standard Class    Corporate    New York City        New York
# 246     Second Class  Home Office        Lakeville       Minnesota
# 381      First Class    Corporate    San Francisco      California
# 8422  Standard Class     Consumer         Lakewood      New Jersey
# 9336  Standard Class    Corporate    San Francisco      California
# 888   Standard Class    Corporate    San Francisco      California
# 1117  Standard Class     Consumer          Roswell         Georgia
# 1990  Standard Class     Consumer      Springfield        Missouri
# 3114  Standard Class     Consumer          Seattle      Washington
# 3944    Second Class     Consumer      Los Angeles      California
# 1327     First Class    Corporate          Norwich     Connecticut
# ...

# %% [markdown]
# Hence, phones and paper are sold with a 100% profit in this store.

# %% [markdown]
# ### CONSUMER LEVEL ANALYSIS

# %%
fig=plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
s=sns.countplot('Segment', data = data)
for s in ax.patches:
    ax.annotate('{:.0f}'.format(s.get_height()), (s.get_x()+0.15, s.get_height()+1))
plt.show()

# %% [markdown]
# The distribution is highest in Consumer Segment.

# %% [markdown]
# Hence, for improving their sales the store must promote more and more products in the Corporate sector and their home office. Also, they must focus on the loss percentage in the products as we analysed above.
#
#
# ******************************************************* The End ***************************************************************
